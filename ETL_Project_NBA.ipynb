# %%
# Dependencies
import pandas as pd

# %%
Player_Salary = "Player_Salary.csv"

# %%
Player_Salary_df = pd.read_csv(Player_Salary)
Player_Salary_df.head()
# Out:
#     Rk             Player   Tm       2019-20       2020-21       2021-22  \
# 0  1.0      Stephen Curry  GSW  $40,231,758   $43,006,362   $45,780,966
# 1  2.0         Chris Paul  OKC  $38,506,482   $41,358,814   $44,211,146
# 2  3.0  Russell Westbrook  HOU  $38,178,000   $41,006,000   $43,848,000
# 3  4.0          John Wall  WAS  $37,800,000   $40,824,000   $43,848,000
# 4  5.0       James Harden  HOU  $37,800,000   $40,824,000   $43,848,000
#
#         2022-23 2023-24 2024-25 Signed Using     Guaranteed
# 0           NaN     NaN     NaN  Bird Rights  $129,019,086
# 1           NaN     NaN     NaN          NaN  $124,076,442
# 2  $46,662,000      NaN     NaN  Bird Rights  $123,032,000
# 3  $46,872,000      NaN     NaN  Bird Rights  $122,472,000
# 4  $46,872,000      NaN     NaN  Bird Rights  $122,472,000

# %%
Player_Basic = "Player_Basic.csv"

# %%
Player_Basic_df = pd.read_csv(Player_Basic)
Player_Basic_df.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
Player_Basic_df = Player_Basic_df.rename(columns={"name":"Player"})
Player_Basic_df.head()
# Out:
#                 Player  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
Player_Basic_df.columns
# Out:
# Index(['Player', 'year_start', 'year_end', 'position', 'height', 'weight',
#        'birth_date', 'college'],
#       dtype='object')

# %%
Player_Basic_df = Player_Basic_df[['Player','year_start','position', 'height', 'weight',
       'birth_date', 'college']]
Player_Basic_df
# Out:
#                    Player  year_start position height  weight  \
# 0          Alaa Abdelnaby        1991      F-C   6-10   240.0
# 1         Zaid Abdul-Aziz        1969      C-F    6-9   235.0
# 2     Kareem Abdul-Jabbar        1970        C    7-2   225.0
# 3      Mahmoud Abdul-Rauf        1991        G    6-1   162.0
# 4       Tariq Abdul-Wahad        1998        F    6-6   223.0
# 5     Shareef Abdur-Rahim        1997        F    6-9   225.0
# 6           Tom Abernethy        1977        F    6-7   220.0
# 7             Forest Able        1957        G    6-3   180.0
# 8          John Abramovic        1947        F    6-3   195.0
# 9            Alex Abrines        2017      G-F    6-6   190.0
# 10             Alex Acker        2006        G    6-5   185.0
# 11           Don Ackerman        1954        G    6-0   183.0
# 12             Mark Acres        1988      F-C   6-11   220.0
# 13              Bud Acton        1968        F    6-6   210.0
# ...

# %%
Player_Stats_19 = "Player_Stats_19.csv"

# %%
Player_Stats_19_df = pd.read_csv(Player_Stats_19)
Player_Stats_19_df.head()
# Out:
#            PLAYER TEAM  AGE  GP   W   L   MIN   PTS  FGM   FGA  ...  REB  AST  \
# 0    Bobby Portis  WAS   24  50  14  36  26.0  14.2  5.6  12.6  ...  8.1  1.4
# 1    Bradley Beal  WAS   26  82  32  50  36.9  25.6  9.3  19.6  ...  5.0  5.5
# 2  Chasson Randle  WAS   26  49  19  30  15.2   5.5  1.9   4.4  ...  1.1  2.0
# 3  Devin Robinson  WAS   24   7   1   6  13.5   6.7  2.7   4.6  ...  2.9  0.9
# 4   Dwight Howard  WAS   33   9   4   5  25.5  12.8  4.8   7.7  ...  9.2  0.4
#
#    TOV  STL  BLK   PF    FP  DD2  TD3  Plusminus
# 0  1.5  0.7  0.4  2.9  27.9   14    0       -2.2
# 1  2.7  1.5  0.7  2.8  43.6   11    2       -1.4
# 2  0.9  0.5  0.1  1.9  10.7    0    0       -2.2
# 3  0.3  0.6  0.9  1.6  15.4    0    0       -1.3
# 4  1.8  0.8  0.4  3.8  26.4    3    0       -5.6
#
# [5 rows x 29 columns]

# %%
Player_Stats_19_df = Player_Stats_19_df.rename(columns={"PLAYER":"Player", "0.625":"3PM"})
Player_Stats_19_df.head()
# Out:
#            Player TEAM  AGE  GP   W   L   MIN   PTS  FGM   FGA  ...  REB  AST  \
# 0    Bobby Portis  WAS   24  50  14  36  26.0  14.2  5.6  12.6  ...  8.1  1.4
# 1    Bradley Beal  WAS   26  82  32  50  36.9  25.6  9.3  19.6  ...  5.0  5.5
# 2  Chasson Randle  WAS   26  49  19  30  15.2   5.5  1.9   4.4  ...  1.1  2.0
# 3  Devin Robinson  WAS   24   7   1   6  13.5   6.7  2.7   4.6  ...  2.9  0.9
# 4   Dwight Howard  WAS   33   9   4   5  25.5  12.8  4.8   7.7  ...  9.2  0.4
#
#    TOV  STL  BLK   PF    FP  DD2  TD3  Plusminus
# 0  1.5  0.7  0.4  2.9  27.9   14    0       -2.2
# 1  2.7  1.5  0.7  2.8  43.6   11    2       -1.4
# 2  0.9  0.5  0.1  1.9  10.7    0    0       -2.2
# 3  0.3  0.6  0.9  1.6  15.4    0    0       -1.3
# 4  1.8  0.8  0.4  3.8  26.4    3    0       -5.6
#
# [5 rows x 29 columns]

# %%
Player_Stats_19_df.columns
# Out:
# Index(['Player', 'TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'PTS', 'FGM', 'FGA',
#        'FG%', '3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB',
#        'AST', 'TOV', 'STL', 'BLK', 'PF', 'FP', 'DD2', 'TD3', 'Plusminus'],
#       dtype='object')

# %%
Player_Stats_19_df = Player_Stats_19_df[['Player','AGE', 'GP', 'W', 'L', 'MIN', 'PTS', 'FGM', 'FGA',
       'FG%','3PM', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB',
       'AST', 'TOV', 'STL', 'BLK','Plusminus']]
Player_Stats_19_df.head()
# Out:
#            Player  AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  ...  FTA  \
# 0    Bobby Portis   24  50  14  36  26.0  14.2  5.6  12.6  44.4  ...  1.9
# 1    Bradley Beal   26  82  32  50  36.9  25.6  9.3  19.6  47.5  ...  5.5
# 2  Chasson Randle   26  49  19  30  15.2   5.5  1.9   4.4  41.9  ...  1.3
# 3  Devin Robinson   24   7   1   6  13.5   6.7  2.7   4.6  59.4  ...  2.0
# 4   Dwight Howard   33   9   4   5  25.5  12.8  4.8   7.7  62.3  ...  5.3
#
#     FT%  OREB  DREB  REB  AST  TOV  STL  BLK  Plusminus
# 0  79.4   2.2   5.9  8.1  1.4  1.5  0.7  0.4       -2.2
# 1  80.8   1.1   3.9  5.0  5.5  2.7  1.5  0.7       -1.4
# 2  69.4   0.2   0.9  1.1  2.0  0.9  0.5  0.1       -2.2
# 3  64.3   0.9   2.0  2.9  0.9  0.3  0.6  0.9       -1.3
# 4  60.4   2.7   6.6  9.2  0.4  1.8  0.8  0.4       -5.6
#
# [5 rows x 24 columns]

# %%
df = pd.merge(Player_Salary_df, Player_Basic_df, how = "inner", on = "Player")
df.head()
# Out:
#     Rk             Player   Tm       2019-20       2020-21       2021-22  \
# 0  1.0      Stephen Curry  GSW  $40,231,758   $43,006,362   $45,780,966
# 1  2.0         Chris Paul  OKC  $38,506,482   $41,358,814   $44,211,146
# 2  3.0  Russell Westbrook  HOU  $38,178,000   $41,006,000   $43,848,000
# 3  4.0          John Wall  WAS  $37,800,000   $40,824,000   $43,848,000
# 4  5.0       James Harden  HOU  $37,800,000   $40,824,000   $43,848,000
#
#         2022-23 2023-24 2024-25 Signed Using     Guaranteed  year_start  \
# 0           NaN     NaN     NaN  Bird Rights  $129,019,086         2010
# 1           NaN     NaN     NaN          NaN  $124,076,442         2006
# 2  $46,662,000      NaN     NaN  Bird Rights  $123,032,000         2009
# 3  $46,872,000      NaN     NaN  Bird Rights  $122,472,000         2011
# 4  $46,872,000      NaN     NaN  Bird Rights  $122,472,000         2010
#
#   position height  weight         birth_date  \
# 0        G    6-3   190.0     March 14, 1988
# ...

# %%
NBA_19 = pd.merge(df, Player_Stats_19_df, how = "inner", on = "Player")
NBA_19.head()
# Out:
#     Rk             Player   Tm       2019-20       2020-21       2021-22  \
# 0  1.0      Stephen Curry  GSW  $40,231,758   $43,006,362   $45,780,966
# 1  2.0         Chris Paul  OKC  $38,506,482   $41,358,814   $44,211,146
# 2  3.0  Russell Westbrook  HOU  $38,178,000   $41,006,000   $43,848,000
# 3  4.0          John Wall  WAS  $37,800,000   $40,824,000   $43,848,000
# 4  5.0       James Harden  HOU  $37,800,000   $40,824,000   $43,848,000
#
#         2022-23 2023-24 2024-25 Signed Using  ...   FTA   FT% OREB DREB   REB  \
# 0           NaN     NaN     NaN  Bird Rights  ...   4.2  91.6  0.7  4.7   5.3
# 1           NaN     NaN     NaN          NaN  ...   3.5  86.2  0.6  3.9   4.6
# 2  $46,662,000      NaN     NaN  Bird Rights  ...   6.2  65.6  1.5  9.6  11.1
# 3  $46,872,000      NaN     NaN  Bird Rights  ...   5.5  69.7  0.5  3.2   3.6
# 4  $46,872,000      NaN     NaN  Bird Rights  ...  11.0  87.9  0.8  5.8   6.6
#
#     AST  TOV  STL  BLK  Plusminus
# ...
